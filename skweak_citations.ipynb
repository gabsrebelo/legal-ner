# %%
import spacy
import csv
import os
import re
import random
from tqdm import tqdm
from skweak.heuristics import FunctionAnnotator
from skweak.base import CombinedAnnotator
from skweak.aggregation import HMM
from skweak.gazetteers import Trie, GazetteerAnnotator
from skweak.utils import display_entities
from skweak import utils

# %% [markdown]
# # Preprocessing

# %%
nlp_pt = spacy.load("pt_core_news_sm")

# %%
path = './Documentos Coletados/'

def extract_from_docs(path):    
    '''Extrai as sentencas a partir de vários arquivos em um diretório'''
    
    files = os.listdir(path)
    docs = []

    for filename in tqdm(files, position=0):
        if os.path.splitext(filename)[1] == ".txt":
            with open(os.path.join(path, filename)) as f:
                file = f.readlines()
                for line in file:
                    if line != '\n':
                        line = line
                        docs.append(nlp_pt(line))
            # docs.extend([nlp_pt(line) for line in file if line != '\n'])

    print('{} files processed'.format(len(files)))
    print('{} sentences found'.format(len(docs)))

# %%
def extract_from_file(filepath):
    '''
    Extrai as sentencas a partir de um único arquivo no qual elas estao separadas por quebra de linha.
    Retorna uma lista de sentencas do tipo Doc do Spacy.
    '''
    
    sentences = []
    with open(filepath) as f:
        lines = f.readlines()
        for l in tqdm(lines, position=0):
            if l != '\n':
                sentences.append(nlp_pt(l))
    
    return sentences

# %%
filepath = './Coleta de sentencas/text_sentences_extracted.txt'
sentences = extract_from_file(filepath)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41834/41834 [02:01<00:00, 343.71it/s]

# %% [markdown]
# # Labelling functions

# %% [markdown]
# ## Detecting generic laws

# %%
def isRoman(token):
    return bool(re.search(r"^M{0,3}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3})$",token))

# %%
def law_detector(doc):
    label = 'LEGISLACAO'
    variations_n = ['n.', 'n.º', 'nº', 'n°.', 'n°']
    variations_law = ['lei', 'decreto-lei', 'decreto', 'lc']
    variations_art = ['arts.', 'arts', 'art.', 'artigo', 'art', 'artigos']
    variations_paragraph = ['parágrafo', 'paragrafo', '§']
    varitions_inciso = ['inciso', 'incisos', 'inc.']
    variations_alinea = ['alinea', 'alínea']
    laws_types = ['federal','complementar','municipal', 'estadual']
    
    
    for token in doc: 
        #identificar leis
        if token.text.lower() in variations_law:
            if token.nbor(1).text[0].isdigit():
                yield token.i, token.i+2, label
            elif token.nbor(1).text.lower() in variations_n and token.nbor(2).text[0].isdigit():
                yield token.i, token.i+3, label
        
        
        elif token.text.lower() == 'lei' and token.nbor(1).text.lower() in laws_types:
            if token.nbor(2).text[0].isdigit(): ##Lei Federal 9.093/95
                yield token.i, token.i+3, label
            if token.nbor(2).text.lower() in variations_n and token.nbor(3).text[0].isdigit(): ##Lei Federal nº 9.093/95
                yield token.i, token.i+3, label
        
        #identificar artigos
        elif token.text.lower() in variations_art:
            if token.nbor(1).text[0].isdigit():
                yield token.i, token.i+2, label
            elif token.nbor(1).text == '.' and token.nbor(2).text[0].isdigit():
                yield token.i, token.i+3, label
        elif token.i > 3 and token.text[0].isdigit():
            if token.nbor(-3).text.lower() == 'arts' or token.nbor(-4).text.lower() == 'arts':
                yield token.i, token.i+1, label
                
        #identificar paragrafos
        elif token.text in variations_paragraph:
            if token.nbor(1).text[0].isdigit():
                yield token.i, token.i+2, label
            elif token.nbor(1).text.lower() == 'único': ##parágrafo único
                yield token.i, token.i+2, label
        
        #identificar incisos
        elif token.text.lower() in varitions_inciso:
            if isRoman(token.nbor(1).text):
                yield token.i, token.i+2, label
                
        elif token.i != 0 and token.i < len(doc)-1 and isRoman(token.text):
            if token.nbor(-1).text in [',','e'] and token.nbor(1).text in [',','e']:
                yield token.i, token.i+1, label
                
        elif token.i > 3 and isRoman(token.text):
            if token.nbor(-3).text.lower() == 'incisos':#<--
                yield token.i, token.i+1, label
                
        #identificar alineas
        elif token.text.lower() in variations_alinea and len(token.nbor(1).text) == 1:
            yield token.i, token.i+2, label
        
        #idenficar caput
        elif token.text.lower() == 'caput':
            yield token.i, token.i+1, label

# %%
law_detector = FunctionAnnotator("law_detector", law_detector)

# %% [markdown]
# ## Detecting named laws

# %%
file = open('./apelidos_leis.csv')
csv_reader = csv.reader(file, delimiter=';')
next(csv_reader) #skip header
names = []
for row in tqdm(csv_reader, total=1046, position=0):
    name = row[1]
    tokenized_name = [t.text for t in nlp_pt(name)]
    names.append(tokenized_name)
# Out:
# 1080it [00:04, 268.09it/s]

# %%
trie = Trie(names)
law_names_detector = GazetteerAnnotator('apelidos', {'LEGISLACAO':trie}, case_sensitive=False)

# %% [markdown]
# ## Apply

# %%
combined = CombinedAnnotator()
combined.add_annotators(law_detector, law_names_detector)

sentences = list(combined.pipe(sentences))

# %% [markdown]
# # Aggregation

# %%
#hmm = HMM("hmm", ["LEGISLACAO","APELIDO"])

# %%
#hmm.fit_and_aggregate([doc])

# %% [markdown]
# # Visualize

# %%
#filter only labeled sentences
sentences_labeled = []
n_labels = 0
for s in sentences:
    if s.spans['law_detector'] or s.spans['apelidos']:
        sentences_labeled.append(s)
        
        #count
        n_labels += len(s.spans['law_detector'])
        n_labels += len(s.spans['apelidos'])
        
    
#docs_labeled = [d for d in docs if d.spans['law_detector'] or d.spans['apelidos']]

print('{} sentences labeled'.format(len(sentences_labeled)))
print('{} labels found'.format(n_labels))
# Out:
# 2526 sentences labeled
# 7362 labels found

# %% [markdown]
# ## Random Sentences

# %%
# random.shuffle(sentences_labeled)
for s in sentences_labeled:
    display_entities(s, ['law_detector','apelidos'])
    print('--------------------------------------')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 2. No caso dos autos não ocorre nenhuma das hipóteses previstas no
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artigo 1.022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     novo CPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , pois o acórdão embargado apreciou as teses relevantes para o deslinde do caso e fundamentou sua conclusão.</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 2. A Corte Especial do STJ já definiu que&quot;para a concessão de tutela de urgência (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 300
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CPC/2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ), há se exigir a presença cumulada dos dois requisitos legais: a probabilidade do direito e o perigo de dano ou risco ao resultado útil do processo. Além disso, exige-se que não haja risco de irreversibilidade da medida&quot;(AgInt na Rcl 34966/RS, DJe de 13/09/2018).</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 3. No tocante ao
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 37
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 6º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Carta Magna
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , o entendimento do Supremo Tribunal Federal a respeito da matéria encontra-se firmado no sentido de que as pessoas jurídicas de direito privado prestadoras de serviço público respondem objetivamente por suas ações ou omissões em face de reparação de</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> “AGRAVO REGIMENTAL NO AGRAVO DE INSTRUMENTO. fundamentos INATACADOS. 1. A agravante não impugnou os fundamentos da decisão agravada. Incidência do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artigo 317
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 1º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RISTF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# . 2. Agravo regimental a que se nega provimento.” (AI nº 664.174/SC-AgR, Segunda Turma, Rel. Min Eros Grau , DJ de 1º/2/08)</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> não apontou violação ao
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 1.022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  para que se possibilitasse a esta Corte</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# . ALEGADO EXCESSO DE PRAZO. NECESSIDADE DE SE AFERIR A DURAÇÃO RAZOÁVEL DO PROCESSO À LUZ DAS ESPECIFICIDADES DO CASO CONCRETO. INADMISSIBILIDADE NA VIA ELEITA. PRETENSÃO DE IMPOSIÇÃO DE PRISÃO DOMICILIAR. TEMA NÃO DEBATIDO PELAS INSTÂNCIAS PRECEDENTES. SUPRESSÃO DE INSTÂNCIA. REVOLVIMENTO DO CONJUNTO FÁTICO-PROBATÓRIO. - Seguimento negado, com esteio no
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artigo 21
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 1º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RISTF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# . Prejudicado o exame do pedido de liminar. - Ciência ao Ministério Público Federal” (HC n. 160.848, Relator o Ministro Luiz Fux, DJe 22.8.2018).</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> É verdade que a hipótese de responsabilidade tributária prevista no
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 135
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CTN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  não impede que o Fisco, administrativamente, desde logo providencie a atribuição da dívida aos sujeitos nele listados (diretores, gerentes, prepostos, mandatários, etc.). Tal medida, porém, costumeiramente é adotada somente no curso da Execução Fiscal quando se verifica que a pessoa jurídica foi dissolvida irregularmente, ou não possui patrimônio suficiente para a quitação do débito – sem prejuízo, evidentemente, da demonstração da prática de atos de infração a lei cometidos pelo responsável tributário.</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 6. Infere-se daí que eventual provimento dos embargos infringentes traria como consequência reformatio in pejus, donde concluir-se que, embora a decisão do Tribunal a quo tenha sido por maioria de votos, não havia interesse jurídico na sua interposição em face do disposto no
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artigo 530
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Código de Processo Civil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  (Se o que se pretende no recurso vai piorar a situação do recorrente, não é de conhecer-se do AI 343841 AGR / DF mesmo por implicar reformatio in pejus: RE 74.168-MA, RTJ 66/207; RE 95.235-RJ, RTJ 104/780; RE 238.671-SP, Maurício Corrêa, j. De 30.10.01, Informativo 248; RE 88.557-SP, Moreira Alves, RTJ 88/672)” (grifei).</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> A decisão proferida em 20 de março de 2020, assentando a permanência dos motivos que levaram à prisão, afasta o excesso de prazo. O
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artigo 316
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Código de Processo Penal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  dispõe sobre a duração da custódia preventiva, fixando o prazo de 90 dias, com a possibilidade de prorrogação, por meio de ato fundamentado. Apresentada motivação suficiente à manutenção, fica afastado constrangimento ilegal.</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CPC/15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  seja drástica, tratou-se da medida efetivamente necessária diante das peculiaridades da hipótese, em que existem inúmeros e fortes indícios de ocultação e de transferência de patrimônio entre familiares, especialmente porque verificadas as condições estabelecidas pela jurisprudência: existência de indícios de que o devedor possua patrimônio expropriável, adoção das medidas em caráter subsidiário, decisão com fundamentação adequada às especificidades da hipótese e observância do contraditório substancial e do postulado da proporcionalidade. Precedente.</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">&quot;Nos termos do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 178
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Constituição da República
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , as normas e os tratados internacionais limitadores da responsabilidade das transportadoras aéreas de passageiros, especialmente as Convenções de Varsóvia e Montreal, têm prevalência em relação ao Código de Defesa do Consumidor&quot;(RE 636.331/RJ, Rel. Ministro GILMAR MENDES, TRIBUNAL PLENO, julgado em 25/05/2017, DJe 13/11/2017)</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 2. A divergência jurisprudencial com fundamento na
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alínea c
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do permissivo constitucional, nos termos do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 1.029
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 1º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CPC/2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  e do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 255
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 1º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RISTJ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , exige comprovação e demonstração, esta, em qualquer caso, com a transcrição dos trechos dos arestos que configurem o dissídio, mencionando-se as circunstâncias que identifiquem ou assemelhem os casos confrontados. Para tanto, não basta a simples transcrição de ementas sem o necessário cotejo analítico, a evidenciar a similitude fática entre os casos apontados e a divergência de interpretações, o que não ocorreu no caso dos autos.</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> O Juízo da Auditoria Militar da Comarca de Campo Grande/MS, no processo nº 0041935-80.2018.8.12.0001, determinou a prisão preventiva do paciente, ocorrida no dia 16 de maio de 2018, ante o suposto cometimento do crime previsto no
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artigo 308
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 1º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  (corrupção passiva com causa de aumento alusiva a infração ao dever funcional), do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Código Penal Militar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# .</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Alega que “o acórdão embargado padece de omissão quanto ao cerne do recurso interposto, isto é, quanto à impossibilidade de alteração de norma com status de lei complementar por lei ordinária. Aí reside a inconstitucionalidade apontada pelo Recorrente: a revogação do direito ao gozo da licença -prêmio por assiduidade garantida aos membros da Procuradoria -Geral da Fazenda Nacional, realizada por meio da Medida Provisória nº 1.522/96, deu-se mediante lei ordinária, e não de lei complementar como exige a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Constituição
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ”.</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 3. Evidenciado o caráter manifestamente protelatório dos embargos de declaração, cabe a aplicação da multa prevista no
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     parágrafo único
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 538
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CPC/1973
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# .</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 9/3/2016: Aos recursos interpostos com fundamento no
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CPC/2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  (relativos a decisões publicadas a partir de 18 de março de 2016) serão exigidos os requisitos de admissibilidade recursal na forma do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     novo CPC
# ...
#     CPC/1973
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  e
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 792
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     novo CPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ) e da Fraude contra a Fazenda Pública (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 185
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CTN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ) para assinalar, como corretamente o fez a Ministra Regina Helena, que&quot;a data do ato de alienação ou oneração de bem ou renda do patrimônio da pessoa jurídica contribuinte ou do patrimônio pessoal do (s) sócio (s) administrador (es) infrator (es), ou seu começo&quot;, é que corresponde ao termo inicial da prescrição para redirecionamento. Acrescenta-se que provar a prática de tal ato é incumbência da Fazenda Pública.</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Para a privação desse direito fundamental da pessoa humana, é indispensável a demonstração da existência da prova da materialidade do crime, da presença de indícios suficientes da autoria e do perigo gerado pelo estado de liberdade do imputado, bem como a ocorrência de um ou mais pressupostos do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artigo 312
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Código de Processo Penal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , que assim dispõe:</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Como se vê, o pedido de destaque feito pelas partes, com base no
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     inciso II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , não produz efeitos automaticamente, visto que submetido a deferimento ou indeferimento pelo relator.</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Ante o exposto, não conheço do recurso na parte referente à correção monetária e aos juros de mora e dou-lhe parcial provimento , a fim de reformar o acórdão recorrido para afastar o direito à integralidade da pensão da ora Recorrida, nos termos do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 932
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     V
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , b, do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  e do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 21
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 2º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RISTF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# . Mantido o direito à paridade. Considerando que o apelo extremo foi interposto sob a égide do CPC/73 e tendo em vista a sucumbência recíproca, distribuam-se os ônus sucumbenciais pro rata, nos</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 4. A validade jurídico-constitucional da correção monetária e dos juros moratórios incidentes sobre as condenações impostas à Fazenda Pública, nos termos previstos pelo
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 1º-F
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lei 9.494/97
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , com a redação da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lei 11.960/2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , foi objeto de debate no STF, em sede de repercussão geral, suscitada no RE 870.947. Na sessão de 20/09/2017, o Plenário do STF proferiu julgamento aprovando a tese de repercussão geral de nº 810, reconhecendo a inconstitucionalidade da atualização monetária das condenações impostas à Fazenda Pública segundo a remuneração oficial da caderneta de poupança.</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 5º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  É inadmissível a reclamação:</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 3. Para se responsabilizar, nos termos do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 135
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     III
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CTN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , o sócio da pessoa jurídica pelo pagamento de dívida tributária, não é necessário que a prova de ter ele agido com excesso de poderes ou infração de lei, contrato social ou estatutos seja necessariamente produzida nos autos do processo de execução ajuizado contra a empresa. Pode o credor identificar uma dessas circunstâncias antes de proposta a ação contra pessoa jurídica e, desde já, ajuizar a execução contra o responsável tributário, uma vez que sua responsabilidade é pessoal (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 135
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     caput
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CTN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ).</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Requer, ao final, “a) o conhecimento e processamento dos presentes Embargos de Declaração, eis que tempestivos e presentes todos os demais requisitos para sua admissibilidade; b) ante a possibilidade de atribuição de efeitos infringentes quando do julgamento desses Embargos de Declaração, a intimação dos Embargados, para, em querendo, manifestarse, nos termos do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artigo 1.023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 2º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Código de Processo Civil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  c) Sejam integralmente acolhidos os presentes Embargos de Declaração, no sentido de (i) nulificar o Acórdão, por inobservância do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artigo 1.021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 3º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ; e (ii) suprir as omissões apontadas, atribuindo excepcionais efeitos infringentes ao julgado; d) A intimação da Embargante, na pessoa de seu advogado, para a sessão de julgamento desses aclaratórios, sob pena de nulidade absoluta do ato.” (doc. 33, fl. 19).</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Inicialmente, quanto à alegada ofensa ao
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 43
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Código Civil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , o Recurso Especial não ultrapassa a admissibilidade, ante o óbice da Súmula 282 do Supremo Tribunal Federal ('É inadmissível o recurso extraordinário, quando não ventilada, na decisão recorrida, a questão federal suscitada').</br></div></span>
# --------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 2. A negativa de incidência da causa especial de diminuição da pena, prevista no
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 33
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     § 4º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lei n. 11.343/2006
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
# , deu-se em razão da convicção do julgador, com base nas provas dos autos, de existir dedicação à atividade criminosa, de modo que, alcançar conclusão inversa, demandaria reexame fático-probatório, inviável na via eleita .</br></div></span>
# --------------------------------------

# %% [markdown]
# ## Split train and test datasets

# %%
test_size_per = 0.15

# %%
split = int(len(sentences_labeled) * (1-test_size_per))
print('Tamanho do conjunto de treinamento: {}'.format(split))
print('Tamanho do conjunto de teste: {}'.format(len(sentences_labeled)-split))
# Out:
# Tamanho do conjunto de treinamento: 2147
# Tamanho do conjunto de teste: 379

# %%
sentences_train_labeled = sentences_labeled[:split]
sentences_test_labeled = sentences_labeled[split:]

# %% [markdown]
# # Save

# %%
def see_tokenization(sentence):
    doc = nlp_pt(sentence)
    for t in doc:
        print(t)

def check_labels_skweak(sentence):
    doc = [nlp_pt(sentence)]
    sentence_labeled = list(combined.pipe(doc))[0]
    display_entities(sentence_labeled, ['law_detector','apelidos'])

# %%
def get_span_indexes(doc, lst_span_labels):
    start_idx = []
    middle_idx = []
    for span_label in lst_span_labels:
        spans = doc.spans[span_label]
        for s in spans:
            start_idx.append(s.start)
            rangee = list(range(s.start+1,s.end))
            middle_idx.extend(rangee)
    
    return start_idx, middle_idx

# %%
def save(docs, output_csv):
    writer = open(output_csv, mode='w')
    
    for doc in docs:
        start_idx, middle_idx = get_span_indexes(doc, ['law_detector', 'apelidos'])
        for token in doc:
            if (token.i in start_idx):
                ent_type = 'B-LEGISLACAO'
            elif (token.i in middle_idx):
                ent_type = 'I-LEGISLACAO'
            elif (token.text == '\n'):
                continue
            else:
                ent_type = 'O'
                
            line = '{} {}\n'.format(token.text, ent_type)
            writer.write(line)
        
        writer.write('\n')
            
    writer.close()

# %%
# save(sentences_labeled, 'dataset_annotated_v3.txt')
# save(sentences_train_labeled, 'train_annotated.txt')
# save(sentences_test_labeled, 'test_annotated.txt')

# %% [markdown]
# **Example**

# %%
spans_law_detector = sentences_labeled[5].spans['law_detector']
for s in spans_law_detector:
    print(s, s.label_)
# Out:
# artigos 33 LEGISLACAO
# Lei nº 11.343/2006 LEGISLACAO

# %%
text = "A hipótese do inciso III compreende a "
check_labels_skweak(text)
see_tokenization(text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A hipótese do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     inciso III
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEGISLACAO</span>
# </mark>
#  compreende a </div></span>
# A
# hipótese
# do
# inciso
# III
# compreende
# a
